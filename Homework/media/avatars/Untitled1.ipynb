# %%
from yahoo_fin import options
from requests_html import HTMLSession

# %%
chain = options.get_options_chain("nflx")
chain['calls']
# Out:
#           Contract Name        ...         Implied Volatility
# 0   NFLX190614C00250000        ...                    119.14%
# 1   NFLX190614C00255000        ...                    121.68%
# 2   NFLX190614C00260000        ...                    115.63%
# 3   NFLX190614C00270000        ...                      0.00%
# 4   NFLX190614C00275000        ...                     97.66%
# 5   NFLX190614C00280000        ...                    103.61%
# 6   NFLX190614C00285000        ...                     90.63%
# 7   NFLX190614C00290000        ...                     84.77%
# 8   NFLX190614C00300000        ...                     73.14%
# 9   NFLX190614C00302500        ...                     61.33%
# 10  NFLX190614C00305000        ...                     70.22%
# 11  NFLX190614C00310000        ...                     64.36%
# 12  NFLX190614C00315000        ...                     87.48%
# 13  NFLX190614C00320000        ...                     59.47%
# ...

# %%
chain['calls']['Last Price']
# Out:
# 0      86.00
# 1      98.25
# 2      93.25
# 3     111.60
# 4      76.55
# 5      83.50
# 6      74.56
# 7      73.21
# 8      62.41
# 9      60.50
# 10     41.90
# 11     43.40
# 12     36.20
# 13     42.90
# 14     38.75
# 15     39.09
# 16     26.95
# 17     31.37
# 18     29.00
# 19     28.10
# 20     27.70
# 21     22.04
# 22     19.93
# 23     17.73
# 24     15.70
# 25     13.50
# 26     11.70
# 27      9.75
# 28      8.25
# 29      6.69
# 30      5.33
# 31      4.15
# 32      3.23
# 33      2.43
# 34      1.77
# 35      1.25
# 36      0.92
# 37      0.63
# 38      0.45
# 39      0.32
# 40      0.23
# 41      0.17
# 42      0.12
# 43      0.10
# 44      0.10
# 45      0.06
# 46      0.10
# 47      0.08
# 48      0.07
# 49      0.03
# 50      0.02
# 51      0.02
# 52      0.04
# 53      0.03
# 54      0.04
# 55      0.11
# 56      0.09
# 57      0.10
# 58      0.10
# 59      0.05
# Name: Last Price, dtype: float64

# %%
merge_data = []
for i in chain:
    merge_data.append(chain[i])

# %%
for i in merge_data:
    for j in i['Last Price']:
        print(type(j))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
from requests_html import HTMLSession
date = options.get_expiration_dates("nflx")
date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-4d19586eb412> in <module>()
#       1 from requests_html import HTMLSession
# ----> 2 date = options.get_expiration_dates("nflx")
#       3 date
#
# /anaconda3/lib/python3.7/site-packages/yahoo_fin/options.py in get_expiration_dates(ticker)
#      72     site = build_options_url(ticker)
#      73
# ---> 74     session = HTMLSession()
#      75     resp = session.get(site)
#      76     resp.html.render()
#
# NameError: name 'HTMLSession' is not defined

# %%
date = options.build_options_url("nflx")
date
# Out:
# 'https://finance.yahoo.com/quote/nflx/options?p=nflx'

# %%
date = options.get_expiration_dates("nflx")
date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7ad04ae32fb2> in <module>()
# ----> 1 date = options.get_expiration_dates("nflx")
#       2 date
#
# /anaconda3/lib/python3.7/site-packages/yahoo_fin/options.py in get_expiration_dates(ticker)
#      72
#      73     session = HTMLSession()
# ---> 74     resp = session.get(site)
#      75     resp.html.render()
#      76
#
# NameError: name 'HTMLSession' is not defined
